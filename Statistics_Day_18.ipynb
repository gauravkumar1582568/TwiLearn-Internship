# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **`Multivariate Plots`**
#
# Multivariate analysis (MVA) is a Statistical procedure for analysis of data involving more than one type of measurement or observation. It may also mean solving problems where more than one dependent variable is analyzed simultaneously with other variables.

# %% [markdown]
# ## **`1. Stacked Bar Plot`**
#
# A stacked chart is a form of bar chart that shows the composition and comparison of a few variables, either relative or absolute, over time. Also called a stacked bar or column chart, they look like a series of columns or bars that are stacked on top of each other.

# %% [markdown]
# ### **`Stacked Chart Case Study`**
#
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ## **`2. Multiple Scatterplot`**
#
# A 3D scatter plot allows the visualization of multivariate data. This scatter plot takes multiple scalar variables and uses them for different axes in phase space. The different variables are combined to form coordinates in the phase space and they are displayed using glyphs and coloured using another scalar variable.

# %% [markdown]
# ### **`Scatterplot Case Study`**
#
# ![Specify_colors_scatter_plot_Seaborn_Python_1.webp](data:image/webp;base64,...)

# %% [markdown]
# ## **`3. Multiple Lineplot`**
#
# A multiplot is a special type of plot that displays multiple Y fields over a single X field.
#
# **X field**. From the data, select the field to display on the horizontal x axis.
#
# **Y fields**. Select one or more fields from the data to display over the range of X field values.

# %% [markdown]
# ### **`Lineplot Case Study`**
#
# ![4wpmu.gif](data:image/gif;base64,...)

# %% [markdown]
# # **Bonus Advanced Charts**
#
# 1. Donut Chart
# 2.   Treemap
# 3. Background Map

# %%
import matplotlib.pyplot as plt
from palettable.colorbrewer.qualitative import Pastel1_7
 
# create data
names = ['groupA', 'groupB', 'groupC', 'groupD']
size = [12,11,3,30]
 
# Create a circle at the center of the plot
my_circle = plt.Circle( (0,0), 0.7, color='white')

from palettable.colorbrewer.qualitative import Pastel1_7
plt.pie(size, labels=names, colors=Pastel1_7.hex_colors)
p = plt.gcf()
p.gca().add_artist(my_circle)

# Show the graph
plt.show()

# %%
# # libraries
import matplotlib.pyplot as plt
import squarify    # pip install squarify (algorithm for treemap)
import pandas as pd

# Create a data frame with sample data
df = pd.DataFrame({'nb_people':[8,3,4,2], 'group':["group A", "group B", "group C", "group D"] })

# plot it
squarify.plot(sizes=df['nb_people'], label=df['group'], alpha=.8 )
plt.axis('off')
plt.show()

# %%
# Import the pandas library
import pandas as pd

# Make a data frame with dots to show on the map
data = pd.DataFrame({
   'lon':[-58, 2, 145, 30.32, -4.03, -73.57, 36.82, -38.5],
   'lat':[-34, 49, -38, 59.93, 5.33, 45.52, -1.29, -12.97],
   'name':['Buenos Aires', 'Paris', 'melbourne', 'St Petersbourg', 'Abidjan', 'Montreal', 'Nairobi', 'Salvador'],
   'value':[10, 12, 40, 70, 23, 43, 100, 43]
}, dtype=str)

data
# Out:
#       lon     lat            name value
# 0     -58     -34    Buenos Aires    10
# 1       2      49           Paris    12
# 2     145     -38       melbourne    40
# 3   30.32   59.93  St Petersbourg    70
# 4   -4.03    5.33         Abidjan    23
# 5  -73.57   45.52        Montreal    43
# 6   36.82   -1.29         Nairobi   100
# 7   -38.5  -12.97        Salvador    43

# %%
# import the library
import folium

# Make an empty map
m = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f7b3899e7fc1499bc211a679b8a4d91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f7b3899e7fc1499bc211a679b8a4d91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f7b3899e7fc1499bc211a679b8a4d91 = L.map(
#                 &quot;map_9f7b3899e7fc1499bc211a679b8a4d91&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_066876f842e948f536341a2bb49f1789 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f7b3899e7fc1499bc211a679b8a4d91);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in range(0,len(data)):
   folium.Marker(
      location=[data.iloc[i]['lat'], data.iloc[i]['lon']],
      popup=data.iloc[i]['name'],
   ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f7b3899e7fc1499bc211a679b8a4d91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f7b3899e7fc1499bc211a679b8a4d91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f7b3899e7fc1499bc211a679b8a4d91 = L.map(
#                 &quot;map_9f7b3899e7fc1499bc211a679b8a4d91&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_066876f842e948f536341a2bb49f1789 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f7b3899e7fc1499bc211a679b8a4d91);
#
#
#             var marker_de0fd556025db3654fc96b6eae4608c1 = L.marker(
#                 [-34.0, -58.0],
#                 {}
#             ).addTo(map_9f7b3899e7fc1499bc211a679b8a4d91);
#
#
#         var popup_68a979bbced636edf58f4ca96c819114 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b461664e49fb8adf787d1ed81ee7db50 = $(`&lt;div id=&quot;html_b461664e49fb8adf787d1ed81ee7db50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buenos Aires&lt;/div&gt;`)[0];
#             popup_68a979bbced636edf58f4ca96c819114.setContent(html_b461664e49fb8adf787d1ed81ee7db50);
#
#
#         marker_de0fd556025db3654fc96b6eae4608c1.bindPopup(popup_68a979bbced636edf58f4ca96c819114)
#         ;
#
#
#
#
#             var marker_71caa3dbc8cd76888dfa206538515493 = L.marker(
#                 [49.0, 2.0],
#                 {}
#             ).addTo(map_9f7b3899e7fc1499bc211a679b8a4d91);
#
#
#         var popup_59ed2530e95b1cfd42e9b1166640c4a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_edfef65881b82ff32a25084c64cda8c3 = $(`&lt;div id=&quot;html_edfef65881b82ff32a25084c64cda8c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris&lt;/div&gt;`)[0];
#             popup_59ed2530e95b1cfd42e9b1166640c4a2.setContent(html_edfef65881b82ff32a25084c64cda8c3);
#
#
#         marker_71caa3dbc8cd76888dfa206538515493.bindPopup(popup_59ed2530e95b1cfd42e9b1166640c4a2)
#         ;
#
#
#
#
#             var marker_df06eb67a8c81931fd93a70677a3785b = L.marker(
#                 [-38.0, 145.0],
#                 {}
#             ).addTo(map_9f7b3899e7fc1499bc211a679b8a4d91);
#
#
#         var popup_30860ccc87ddc1699ce10630a71fc860 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a4ba96d5d0c8ab3c1cce6588214545eb = $(`&lt;div id=&quot;html_a4ba96d5d0c8ab3c1cce6588214545eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;melbourne&lt;/div&gt;`)[0];
#             popup_30860ccc87ddc1699ce10630a71fc860.setContent(html_a4ba96d5d0c8ab3c1cce6588214545eb);
#
#
#         marker_df06eb67a8c81931fd93a70677a3785b.bindPopup(popup_30860ccc87ddc1699ce10630a71fc860)
#         ;
#
#
#
#
#             var marker_c6470e61d3d42ef1ef9d23a1a2e656f7 = L.marker(
#                 [59.93, 30.32],
#                 {}
#             ).addTo(map_9f7b3899e7fc1499bc211a679b8a4d91);
#
#
#         var popup_6e05783a30490adb181206a171d38220 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_405532ccbe7ae50171516c1830dbb4f2 = $(`&lt;div id=&quot;html_405532ccbe7ae50171516c1830dbb4f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St Petersbourg&lt;/div&gt;`)[0];
#             popup_6e05783a30490adb181206a171d38220.setContent(html_405532ccbe7ae50171516c1830dbb4f2);
#
#
#         marker_c6470e61d3d42ef1ef9d23a1a2e656f7.bindPopup(popup_6e05783a30490adb181206a171d38220)
#         ;
#
#
#
#
#             var marker_e390d899985574dc8c9861c743da06ee = L.marker(
#                 [5.33, -4.03],
#                 {}
#             ).addTo(map_9f7b3899e7fc1499bc211a679b8a4d91);
#
#
#         var popup_e08d9700193effb5cc997ffb4bc94519 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_494e927e35efccf625918501d018d78f = $(`&lt;div id=&quot;html_494e927e35efccf625918501d018d78f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abidjan&lt;/div&gt;`)[0];
#             popup_e08d9700193effb5cc997ffb4bc94519.setContent(html_494e927e35efccf625918501d018d78f);
#
#
#         marker_e390d899985574dc8c9861c743da06ee.bindPopup(popup_e08d9700193effb5cc997ffb4bc94519)
#         ;
#
#
#
#
#             var marker_d73a317dc74529741e4a0011018bc20c = L.marker(
#                 [45.52, -73.57],
#                 {}
#             ).addTo(map_9f7b3899e7fc1499bc211a679b8a4d91);
#
#
#         var popup_b2db6cceacb8afc2bd923a7d366ecdd6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1916619baa17e7cea6516db7cfd033b3 = $(`&lt;div id=&quot;html_1916619baa17e7cea6516db7cfd033b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Montreal&lt
